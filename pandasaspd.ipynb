# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\samud\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\samud\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
# ...

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
vinay_1 = [1,2,-3, 0.4 ,"data values"]
print(vinay_1)
# Out:
# [1, 2, -3, 0.4, 'data values']

# %%
series_1 = pd.Series(vinay_1)
print(series_1)
# Out:
# 0              1
# 1              2
# 2             -3
# 3            0.4
# 4    data values
# dtype: object

# %%
type(series_1)
# Out:
# pandas.core.series.Series

# %%
series_2 = pd.Series([1,2,3,4,5])
print(series_2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#empty series 
empty_1 = pd.Series([])
print(empty_1)
# Out:
# Series([], dtype: object)

# %%
series_3 = pd.Series([1,2,3,4,5] ,index = ["a","b","c","d","e"])
print(series_3)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
series_3 = pd.Series([1,2,3,4,5] ,index = ["a","b","c","d","e"] , dtype = float)
print(series_3)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %%
series_3 = pd.Series([1,2,3,4,5] ,index = ["a","b","c","d","e"] , dtype = int,  name = 'data values')
print(series_3)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: data values, dtype: int64

# %% [markdown]
# # for single value also know as single scalar values

# %%
scalar_1 = pd.Series(0.5)
print(scalar_1)
# Out:
# 0    0.5
# dtype: float64

# %%
# smoetimes for single sclar values we use the index 
scalar_1 = pd.Series(0.5 ,index = [1,2,3,4])
print(scalar_1)
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# 4    0.5
# dtype: float64

# %%
scalar_1 = pd.Series(0.5 ,index = [1,2,3,4] ,name ='vinay')
print(scalar_1)
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# 4    0.5
# Name: vinay, dtype: float64

# %%
# we can create the series also dictionay from

# %%
dic_1 = pd.Series({'a':1,'b':2})
print(dic_1)
# Out:
# a    1
# b    2
# dtype: int64

# %% [markdown]
# # in pandas we can use the slicing also

# %%
s4 = pd .Series([1,2,3,4])
print(s4)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s4[0]
# Out:
# np.int64(1)

# %%
s4[0:4]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s4[1:4]
# Out:
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
max(s4)
# Out:
# 4

# %%
min(s4)
# Out:
# 1

# %% [markdown]
# # how to create python pandas dataframes

# %%
import pandas as pd

# %%
# create the empty data frames

# %%
vinay_1d = pd.DataFrame()
print(vinay_1d)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
list = [ 'a','b','c','d']
print(list)
# Out:
# ['a', 'b', 'c', 'd']

# %%
df_1 = pd.DataFrame(list)
print(df_1)
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d

# %%
df_1
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d

# %%
vinay1_of_vinay2 = [[1,2,3],[4,5,6],[7,8,9]]
print(vinay1_of_vinay2)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df_2 = pd.DataFrame(vinay1_of_vinay2)
print(df_2)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df_2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
#we can also chcek by help of dictionary

# %%
df_3 = {"vinay": [1,2,3,4,5]}
print(df_3)
# Out:
# {'vinay': [1, 2, 3, 4, 5]}

# %%
df_4 = pd.DataFrame(df_3)
print(df_4)
# Out:
#    vinay
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %%
df_4
# Out:
#    vinay
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %%
df_3 = {"vinay": [1,2,3,4,5] , "samu":[6,7,8,9,10]}
print(df_3)
# Out:
# {'vinay': [1, 2, 3, 4, 5], 'samu': [6, 7, 8, 9, 10]}

# %%
df_4 = pd.DataFrame(df_3)
print(df_4)
# Out:
#    vinay  samu
# 0      1     6
# 1      2     7
# 2      3     8
# 3      4     9
# 4      5    10

# %%
df_4
# Out:
#    vinay  samu
# 0      1     6
# 1      2     7
# 2      3     8
# 3      4     9
# 4      5    10

# %%
import pandas as pd

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv")
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %% [markdown]
# # if you do not any information csv file where they save then we ccan use the os function

# %% [markdown]
# # os function

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\samud

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv")
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address',
#        'salary'],
#       dtype='object')

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv", nrows = 10)
df
# Out:
#    id first_name   last_name                    email       gender  \
# 0   1    Hadrian      Bridie      hbridie0@cdbaby.com         Male
# 1   2       Doll       Gawne         dgawne1@phoca.cz       Female
# 2   3      Decca        Prop      dprop2@redcross.org          NaN
# 3   4       Babs       Lande         blande3@xing.com  Genderqueer
# 4   5    Barrett    O'Brogan      bobrogan4@wikia.com         Male
# 5   6      Kenon       Quigg          kquigg5@cdc.gov         Male
# 6   7    Salomon  Murricanes  smurricanes6@unicef.org         Male
# 7   8   Joycelin     Whether   jwhether7@hatena.ne.jp       Female
# 8   9    Gardner    McIllroy     gmcillroy8@jimdo.com         Male
# 9  10     Mollie   Runnicles    mrunnicles9@yahoo.com       Female
#
#        ip_address    salary
# 0   112.160.37.12   93144.0
# 1   229.3.141.136   69531.0
# 2  104.75.204.218       NaN
# 3  238.182.87.171   94304.0
# 4   104.60.27.200  117200.0
# 5   62.109.223.68  128071.0
# ...

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv", nrows = 1) ,# for rows
df
# Out:
# (   id first_name last_name                email gender     ip_address  salary
#  0   1    Hadrian    Bridie  hbridie0@cdbaby.com   Male  112.160.37.12   93144,)

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv" , usecols =[0]) # for columns 
df
# Out:
#        id
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 995   996
# 996   997
# 997   998
# 998   999
# 999  1000
#
# [1000 rows x 1 columns]

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv" , usecols =[1,2,3]) # for columns 
df
# Out:
#     first_name last_name                  email
# 0      Hadrian    Bridie    hbridie0@cdbaby.com
# 1         Doll     Gawne       dgawne1@phoca.cz
# 2        Decca      Prop    dprop2@redcross.org
# 3         Babs     Lande       blande3@xing.com
# 4      Barrett  O'Brogan    bobrogan4@wikia.com
# ..         ...       ...                    ...
# 995     Maxine   Drayson  mdraysonrn@utexas.edu
# 996     Hurlee     Joule      hjoulero@lulu.com
# 997    Richart   Koschke   rkoschkerp@patch.com
# 998     Giffie   Merring   gmerringrq@tmall.com
# 999     Giorgi  Winspare     gwinsparerr@gov.uk
#
# [1000 rows x 3 columns]

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv" , skiprows = [0,1,2])  
df
# Out:
#         3     Decca        Prop      dprop2@redcross.org   Unnamed: 4  \
# 0       4      Babs       Lande         blande3@xing.com  Genderqueer
# 1       5   Barrett    O'Brogan      bobrogan4@wikia.com         Male
# 2       6     Kenon       Quigg          kquigg5@cdc.gov         Male
# 3       7   Salomon  Murricanes  smurricanes6@unicef.org         Male
# 4       8  Joycelin     Whether   jwhether7@hatena.ne.jp       Female
# ..    ...       ...         ...                      ...          ...
# 992   996    Maxine     Drayson    mdraysonrn@utexas.edu       Female
# 993   997    Hurlee       Joule        hjoulero@lulu.com         Male
# 994   998   Richart     Koschke     rkoschkerp@patch.com         Male
# 995   999    Giffie     Merring     gmerringrq@tmall.com         Male
# 996  1000    Giorgi    Winspare       gwinsparerr@gov.uk          NaN
#
#       104.75.204.218  Unnamed: 6
# 0     238.182.87.171     94304.0
# 1      104.60.27.200    117200.0
# ...

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv" , index_col = "first_name" ) 
df
# Out:
#               id last_name                  email       gender  \
# first_name
# Hadrian        1    Bridie    hbridie0@cdbaby.com         Male
# Doll           2     Gawne       dgawne1@phoca.cz       Female
# Decca          3      Prop    dprop2@redcross.org          NaN
# Babs           4     Lande       blande3@xing.com  Genderqueer
# Barrett        5  O'Brogan    bobrogan4@wikia.com         Male
# ...          ...       ...                    ...          ...
# Maxine       996   Drayson  mdraysonrn@utexas.edu       Female
# Hurlee       997     Joule      hjoulero@lulu.com         Male
# Richart      998   Koschke   rkoschkerp@patch.com         Male
# Giffie       999   Merring   gmerringrq@tmall.com         Male
# Giorgi      1000  Winspare     gwinsparerr@gov.uk          NaN
#
#                  ip_address    salary
# first_name
# Hadrian       112.160.37.12   93144.0
# Doll          229.3.141.136   69531.0
# Decca        104.75.204.218       NaN
# ...

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv" ,header = 1 )

# %%
df
# Out:
#         1  Hadrian    Bridie    hbridie0@cdbaby.com         Male  \
# 0       2     Doll     Gawne       dgawne1@phoca.cz       Female
# 1       3    Decca      Prop    dprop2@redcross.org          NaN
# 2       4     Babs     Lande       blande3@xing.com  Genderqueer
# 3       5  Barrett  O'Brogan    bobrogan4@wikia.com         Male
# 4       6    Kenon     Quigg        kquigg5@cdc.gov         Male
# ..    ...      ...       ...                    ...          ...
# 994   996   Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 995   997   Hurlee     Joule      hjoulero@lulu.com         Male
# 996   998  Richart   Koschke   rkoschkerp@patch.com         Male
# 997   999   Giffie   Merring   gmerringrq@tmall.com         Male
# 998  1000   Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#        112.160.37.12     93144
# 0      229.3.141.136   69531.0
# 1     104.75.204.218       NaN
# 2     238.182.87.171   94304.0
# 3      104.60.27.200  117200.0
# ...

# %%
df.head()
# Out:
#    1  Hadrian    Bridie  hbridie0@cdbaby.com         Male   112.160.37.12  \
# 0  2     Doll     Gawne     dgawne1@phoca.cz       Female   229.3.141.136
# 1  3    Decca      Prop  dprop2@redcross.org          NaN  104.75.204.218
# 2  4     Babs     Lande     blande3@xing.com  Genderqueer  238.182.87.171
# 3  5  Barrett  O'Brogan  bobrogan4@wikia.com         Male   104.60.27.200
# 4  6    Kenon     Quigg      kquigg5@cdc.gov         Male   62.109.223.68
#
#       93144
# 0   69531.0
# 1       NaN
# 2   94304.0
# 3  117200.0
# 4  128071.0

# %%
#head function will be used in print only 5 rows

# %%
df.head(2)
# Out:
#    1 Hadrian Bridie  hbridie0@cdbaby.com    Male   112.160.37.12    93144
# 0  2    Doll  Gawne     dgawne1@phoca.cz  Female   229.3.141.136  69531.0
# 1  3   Decca   Prop  dprop2@redcross.org     NaN  104.75.204.218      NaN

# %%
df.tail()
# Out:
#         1  Hadrian    Bridie    hbridie0@cdbaby.com    Male    112.160.37.12  \
# 994   996   Maxine   Drayson  mdraysonrn@utexas.edu  Female  154.175.183.168
# 995   997   Hurlee     Joule      hjoulero@lulu.com    Male   125.113.145.75
# 996   998  Richart   Koschke   rkoschkerp@patch.com    Male  104.236.121.243
# 997   999   Giffie   Merring   gmerringrq@tmall.com    Male     112.53.45.36
# 998  1000   Giorgi  Winspare     gwinsparerr@gov.uk     NaN   122.46.136.150
#
#         93144
# 994  180212.0
# 995  236014.0
# 996   54435.0
# 997   59692.0
# 998       NaN

# %%
#tail function we use by print the bottom 5 rows of seris andmhead funtion for first 5 rows

# %%
df.tail(3)
# Out:
#         1  Hadrian    Bridie   hbridie0@cdbaby.com  Male    112.160.37.12  \
# 996   998  Richart   Koschke  rkoschkerp@patch.com  Male  104.236.121.243
# 997   999   Giffie   Merring  gmerringrq@tmall.com  Male     112.53.45.36
# 998  1000   Giorgi  Winspare    gwinsparerr@gov.uk   NaN   122.46.136.150
#
#        93144
# 996  54435.0
# 997  59692.0
# 998      NaN

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv",dtype = {"id":"float64"})

# %%
df
# Out:
#          id first_name last_name                  email       gender  \
# 0       1.0    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2.0       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3.0      Decca      Prop    dprop2@redcross.org          NaN
# 3       4.0       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5.0    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..      ...        ...       ...                    ...          ...
# 995   996.0     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997.0     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998.0    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999.0     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000.0     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# ...

# %% [markdown]
# # file handling missing values

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv")

# %%
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv")

# %%
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\mock data 1.csv")

# %%
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca       NaN    dprop2@redcross.org          NaN
# 3       4       Babs       NaN       blande3@xing.com  Genderqueer
# 4       5    Barrett       NaN    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv")

# %%
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %% [markdown]
# # pandas fillna()

# %%
import pandas as pd

# %%
 df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv")
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
df.fillna(12)
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org           12
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk           12
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218      12.0
# 3     238.182.87.171   94304.0
# ...

# %%
df.fillna({"gender":"male"})
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org         male
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk         male
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
df.fillna(method = 'bfill')
# Out:
# C:\Users\samud\AppData\Local\Temp\ipykernel_1264\3673297803.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'bfill')
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org  Genderqueer
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# ...

# %%
df.fillna(method = 'ffill')
# Out:
# C:\Users\samud\AppData\Local\Temp\ipykernel_1264\1145651979.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'ffill')
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org       Female
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# ...

# %% [markdown]
# # this methode we can use throgh the previous value

# %%
df.fillna(method = 'pad')
# Out:
# C:\Users\samud\AppData\Local\Temp\ipykernel_1264\2275225546.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'pad')
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org       Female
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# ...

# %%
df.fillna(method = "ffill", axis =0)
# Out:
# C:\Users\samud\AppData\Local\Temp\ipykernel_1264\2775819733.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "ffill", axis =0)
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org       Female
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# ...

# %%
df.fillna(method = "pad",axis =1)
# Out:
# C:\Users\samud\AppData\Local\Temp\ipykernel_1264\1782707559.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = "pad",axis =1)
#        id first_name last_name                  email               gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com                 Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz               Female
# 2       3      Decca      Prop    dprop2@redcross.org  dprop2@redcross.org
# 3       4       Babs     Lande       blande3@xing.com          Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com                 Male
# ..    ...        ...       ...                    ...                  ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu               Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com                 Male
# ...

# %% [markdown]
# # axis we can use to the fill the NAn values of the dataframe in the from of rows and columms 0 refers the rows and 1 refers the colums

# %%
df.fillna(0, limit =1 ) # limit is greter thean zero
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org            0
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       0.0
# 3     238.182.87.171   94304.0
# ...

# %% [markdown]
# # inplace is crete for true for false for bollen equations

# %%
df.fillna(5, inplace = True)

# %%
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org            5
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk            5
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       5.0
# 3     238.182.87.171   94304.0
# ...

# %% [markdown]
# # pandas replce

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\samud\\Downloads\\MOCK_DATA.csv")
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...

# %%
df.replace(to_replace = " Bridie " , value ="Prop")
df
# Out:
#        id first_name last_name                  email       gender  \
# 0       1    Hadrian    Bridie    hbridie0@cdbaby.com         Male
# 1       2       Doll     Gawne       dgawne1@phoca.cz       Female
# 2       3      Decca      Prop    dprop2@redcross.org          NaN
# 3       4       Babs     Lande       blande3@xing.com  Genderqueer
# 4       5    Barrett  O'Brogan    bobrogan4@wikia.com         Male
# ..    ...        ...       ...                    ...          ...
# 995   996     Maxine   Drayson  mdraysonrn@utexas.edu       Female
# 996   997     Hurlee     Joule      hjoulero@lulu.com         Male
# 997   998    Richart   Koschke   rkoschkerp@patch.com         Male
# 998   999     Giffie   Merring   gmerringrq@tmall.com         Male
# 999  1000     Giorgi  Winspare     gwinsparerr@gov.uk          NaN
#
#           ip_address    salary
# 0      112.160.37.12   93144.0
# 1      229.3.141.136   69531.0
# 2     104.75.204.218       NaN
# 3     238.182.87.171   94304.0
# ...
